# %%
import pandas as pd
import spacy
from spacy.training import Example
from spacy.util import minibatch, compounding
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, precision_score, recall_score, f1_score, accuracy_score

# %%
data = pd.read_csv('annotated_data.csv', encoding='utf-8')
data.head()
# Out:
#     BrandName                                        Description  \
# 0    roadster  mid clean fit navy look men slim jeans roadste...
# 1  locomotive  black track fit white solid pants locomotive m...
# 2    roadster  roadster men sustainable casual navy white geo...
# 3      zivame  shapewear black zivame saree women zi3023core0...
# 4    roadster  neck women white t pure cotton roadster v shir...
#
#            Annotations
# 0  [(39, 47, 'BRAND')]
# 1  [(34, 44, 'BRAND')]
# 2    [(0, 8, 'BRAND')]
# 3  [(16, 22, 'BRAND')]
# 4  [(31, 39, 'BRAND')]

# %%
data['Annotations'] = data['Annotations'].apply(eval)

train_data,val_data = train_test_split(data, test_size=0.3, random_state=42) 
TRAIN_DATA = [(row['Description'], {'entities': row['Annotations']}) for index, row in train_data.iterrows()]
VALIDATION_DATA = [(row['Description'], {'entities': row['Annotations']}) for index, row in val_data.iterrows()]

# %%
nlp = spacy.blank('en')

ner = nlp.add_pipe('ner', last=True)

for _, annotations in TRAIN_DATA:
    for ent in annotations['entities']:
        ner.add_label(ent[2])

misaligned_data = []

def check_and_store_misalignment(text, annotations):
    try:
        example = Example.from_dict(nlp.make_doc(text), annotations)
        return example
    except Exception as e:
        misaligned_data.append((text, annotations))
        return None

train_examples = []
for text, annotations in TRAIN_DATA:
    example = check_and_store_misalignment(text, annotations)
    if example is not None:
        train_examples.append(example)
val_examples = []
for text, annotations in VALIDATION_DATA:
    example = check_and_store_misalignment(text, annotations)
    if example is not None:
        val_examples.append(example)

pipe_exceptions = ["ner"]
other_pipes = [pipe for pipe in nlp.pipe_names if pipe not in pipe_exceptions]

with nlp.disable_pipes(*other_pipes):
    optimizer = nlp.begin_training()
    for iteration in range(10):
        losses = {}
        batches = minibatch(train_examples, size=compounding(4.0, 32.0, 1.001))
        for batch in batches:
            nlp.update(batch, drop=0.5, losses=losses)
        print(f"Iteration {iteration}, Losses: {losses}")

nlp.to_disk("ner_fashion_model")

import json

with open("misaligned_data.json", "w") as f:
    json.dump(misaligned_data, f)
# Out:
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "dress women blue white a line midi floral w" with entities "[(6, 7, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "top women skirt w sustainable yellow with mustard ..." with entities "[(4, 5, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "women solid fit rise cotton teal tights skinny w m..." with entities "[(0, 1, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "women blue w printed kurta straight" with entities "[(0, 1, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "pink blue women coral panelled straight printed ku..." with entities "[(10, 11, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "yellow dupatta kurta stones and with embroidered w..." with entities "[(5, 6, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "top with blue palazzos os ethnic turquoise women p..." with entities "[(20, 22, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "blue white w maxi skirt printed women" with entities "[(5, 6, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "yellow colourblocked women blue w dress empire" with entities "[(5, 6, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "women pink printed motifs ethnic off pastels w kur..." with entities "[(0, 1, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "folksong women print ajrakh kurta w green the coll..." with entities "[(9, 10, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "dupatta cotton striped off white pure w" with entities "[(27, 28, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "trousers women w striped beige blue parallel" with entities "[(9, 10, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "black solid leggings women w churidar" with entities "[(21, 22, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "trunks pack 4 onncomfortzastnr355 onn men of" with entities "[(14, 17, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "women printed maxi grey dress max" with entities "[(14, 17, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "women solid w coloured straight kurta peach" with entities "[(0, 1, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "men briefs solid of onnplatina971spbumos2pc basic ..." with entities "[(20, 23, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "regular women trousers black w cropped" with entities "[(8, 9, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "onngrandeastnf264 pack onn men 5 trunks of" with entities "[(0, 3, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "women white flared w palazzos grey printed" with entities "[(0, 1, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "floral yellow a printed golden w line dress mustar..." with entities "[(12, 13, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "line pink women w a printed dress" with entities "[(10, 11, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "blue printed casual women pink w shirt" with entities "[(20, 21, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "kurta women pathani white yellow striped w" with entities "[(6, 7, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "black trunks speedofit speedo swimming men" with entities "[(13, 19, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "yoke kurta women ethnic w thread work motifs red d..." with entities "[(11, 12, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "women printed rose ethnic motifs kurta w" with entities "[(0, 1, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "white w ethnic maxi striped jacket blue with dress..." with entities "[(0, 1, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "maxi nightdress blue teal printed max cotton women" with entities "[(0, 3, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "geometric blue design women yoke embroidered w kur..." with entities "[(22, 23, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "trousers women w dupatta yellow kurta with with" with entities "[(9, 10, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "sheer sleeveless white front colourblock open w lo..." with entities "[(17, 18, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "flared palazzos women magenta solid w" with entities "[(16, 17, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "ankle solid women grey w charcoal leggings length" with entities "[(12, 13, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "women yellow kurta solid w" with entities "[(0, 1, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "printed white w women trousers" with entities "[(8, 9, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "joggers beige cashmere knit fine hm women" with entities "[(17, 19, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "thread work women kurta green w" with entities "[(7, 8, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "white w high printed women low top" with entities "[(0, 1, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "a layered dress beige maroon line women printed w" with entities "[(34, 35, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "top puff sleeves crop solid pink women regular uf" with entities "[(5, 7, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "quirky kurta printed women w black" with entities "[(21, 22, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "kurta solid women yellow w mustard straight" with entities "[(12, 13, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "work embroidered geometric thread w kurta blue wom..." with entities "[(0, 1, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "solid women churidar shimmery grey length leggings..." with entities "[(6, 7, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "thread work geometric w kurta printed women green" with entities "[(7, 8, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "ethnic women blue w printed straight kurta silver" with entities "[(7, 8, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "top collar purple mandarin sleeve and solid puff" with entities "[(19, 22, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "white women trousers w" with entities "[(0, 1, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "saffron threadswomen turquoise blue floral printed..." with entities "[(0, 15, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "maxi nightdress women max size plus cotton pink pr..." with entities "[(0, 3, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "solid churidar wishful women length by black w leg..." with entities "[(15, 16, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "etnic off golden white printed jacket tiered tie f..." with entities "[(17, 18, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "coloured kurta neck keyhole printed ethnic cream w..." with entities "[(49, 50, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "white slip kurta solid w" with entities "[(0, 1, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "line printed navy women a w kurta blue" with entities "[(18, 19, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "motifs work women thread sleeves w flared yoke eth..." with entities "[(7, 8, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "marks spencermen set of 3 cotton boxers" with entities "[(0, 13, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "white w fit slim women trousers" with entities "[(0, 1, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "yellow mustard line a w dress midi" with entities "[(5, 6, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "women w striped self palazzos leg peach coloured w..." with entities "[(0, 1, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "kurta sequins motifs pink white printed cotton eth..." with entities "[(26, 27, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "tights acrylic women w black solid" with entities "[(15, 16, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "blend sequinned geometric silk sangriared saree" with entities "[(31, 38, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "women white work embroidered purple kurta thread w" with entities "[(0, 1, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "regular fit trousers women w navy cropped solid" with entities "[(21, 22, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "havida sareeswomen yellow striped saree" with entities "[(0, 13, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "maxi black nightdress max printed" with entities "[(0, 3, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "white black front w open printed jacket longline w..." with entities "[(0, 1, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "white w slim fit off printed coloured peach women ..." with entities "[(0, 1, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "blue navy women embroidered silver kurta straight ..." with entities "[(10, 11, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "yellow sustainable a line dress white printed w fo..." with entities "[(5, 6, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "women kurta charcoal white off printed straight w ..." with entities "[(0, 1, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "dress maxi floral white w" with entities "[(18, 19, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "forever 21women pink solid puff sleeve regular top" with entities "[(0, 10, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "women trousers pleated w white" with entities "[(0, 1, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "woven women zari design golden straight red w kurt..." with entities "[(0, 1, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "green printed women casual shirt w" with entities "[(14, 15, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "off pastels work kurta dyed pink white women threa..." with entities "[(12, 13, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "cotton dupatta pink white printed pure w women" with entities "[(20, 21, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "kurta yoke women w straight blue design" with entities "[(11, 12, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "solid regular women cropped trousers green w fit s..." with entities "[(14, 15, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "white maxi w off skirt flared embellished" with entities "[(0, 1, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "maxi dress blue floral max" with entities "[(0, 3, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "white dupatta design silver woven w" with entities "[(0, 1, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "flared off skirt maxi white length printed women w..." with entities "[(22, 23, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "regular fit parallel women w trousers black" with entities "[(21, 22, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "women w sequinned grey kurta floral" with entities "[(0, 1, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "women w trousers toned gold" with entities "[(0, 1, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "grey women maxi max nightdress printed" with entities "[(11, 14, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "coloured nightdress printed maxi peach max" with entities "[(28, 31, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "women white lime kurta printed w sequinned ethnic ..." with entities "[(0, 1, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "design geometric straight yoke women w black kurta..." with entities "[(31, 32, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "flared maxi women skirt printed beige w" with entities "[(12, 13, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "lime palazzos wide with leg w women pleats green s..." with entities "[(14, 15, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "pack 2 colourblocked sports multicoloured klotthem..." with entities "[(42, 49, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "golden cropped cigarette self trousers slim fit wo..." with entities "[(48, 49, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "size women w plus cotton printed kurta burgundy" with entities "[(5, 6, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "tailored women pink w acrylic longline jacket wome..." with entities "[(9, 10, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "straight women orange w solid kurta coral" with entities "[(9, 10, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "dupatta with blue sharara with women layered w kur..." with entities "[(8, 9, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "dupatta work thread blue toned with gold w organza" with entities "[(8, 9, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "red yoke with women empire design sharara w kurti" with entities "[(9, 10, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "slim regular fit solid trousers women pink cropped..." with entities "[(32, 33, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "trousers women w with dupatta pleated kurti green ..." with entities "[(9, 10, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "women maxi nightdress grey printed melange max" with entities "[(6, 9, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "women black kurta w straight printed white" with entities "[(0, 1, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "with dupatta ethnic work w thread motifs organza r..." with entities "[(0, 1, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "ethnic embroidered flared motifs sleeves women kur..." with entities "[(41, 42, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "dress printed women w coloured off peach maxi whit..." with entities "[(14, 15, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "motifs ethnic grey women white kurta printed w" with entities "[(19, 20, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "coloured mauve skirt women printed maxi flared max..." with entities "[(35, 38, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "jc collectionwomen pink black printed dress" with entities "[(0, 13, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "nightdress olive maxi green max printed" with entities "[(17, 20, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# ...
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "floral maxi green max dress" with entities "[(7, 10, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "lavender solid women tights w" with entities "[(15, 16, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "kurta lime pure cotton solid women green w" with entities "[(29, 30, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "tights women black solid w" with entities "[(7, 8, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "pants the solid slim women w ecru collection folks..." with entities "[(21, 22, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "maxi max and tie dyed dye white dress off" with entities "[(0, 3, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "organza motifs white dupatta ethnic blue printed w" with entities "[(15, 16, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "striped blue maxi dress max midi" with entities "[(13, 16, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "dupatta women w kurta with with blue floral palazz..." with entities "[(8, 9, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "kurta printed yellow ethnic women w motifs" with entities "[(19, 20, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "of pack men 3 genxfltmtkoe3pc trunks assorted genx" with entities "[(14, 18, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "design motifs beige mandarin a kurta women ethnic ..." with entities "[(37, 38, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "a solid line black women w dress" with entities "[(19, 20, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "women w pink tights solid" with entities "[(0, 1, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "leg grey solid wide palazzos w women" with entities "[(15, 16, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "fit cropped black women w regular trousers solid s..." with entities "[(18, 19, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "women grey yellow w printed floral skirt tiered" with entities "[(0, 1, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "women yellow kurta embroidered neck ethnic motifs ..." with entities "[(0, 1, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "golden skirt printed white off w maxi flared" with entities "[(21, 22, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "maxi max cotton black conversational pure printed ..." with entities "[(0, 3, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "women white trousers w striped" with entities "[(0, 1, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "work geometric thread women blue kurta w" with entities "[(0, 1, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "kurta blue straight women w" with entities "[(20, 21, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "maxi a pink line dress max" with entities "[(0, 3, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "women trousers white fit slim w" with entities "[(0, 1, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "dress black maxi floral shoulder max off" with entities "[(12, 15, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "maxi printed navy nightdress max women blue" with entities "[(0, 3, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "brown leggings w" with entities "[(3, 4, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "women woven shawl coloured design w silver" with entities "[(0, 1, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "women thread cotton w white with trousers work kur..." with entities "[(0, 1, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "white printed kurti off w pink" with entities "[(0, 1, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "printed women kurta pink chikankari w" with entities "[(8, 9, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "detail a women w top line printed black striped wi..." with entities "[(9, 10, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "women top with a embroidered off trousers w blue w..." with entities "[(0, 1, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "kurta printed straight golden women w orange" with entities "[(30, 31, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "women w ethnic blue printed white motifs kurta" with entities "[(0, 1, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/yashrajsingh/anaconda3/lib/python3.11/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "dupatta women white yellow printed w" with entities "[(8, 9, 'BRAND')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# Iteration 0, Losses: {'ner': 32999.286198553295}
# Iteration 1, Losses: {'ner': 12191.21977536708}
# Iteration 2, Losses: {'ner': 8998.343407670412}
# Iteration 3, Losses: {'ner': 7603.965779417678}
# Iteration 4, Losses: {'ner': 6949.384328991829}
# Iteration 5, Losses: {'ner': 6629.0588964311}
# Iteration 6, Losses: {'ner': 6184.089366248562}
# Iteration 7, Losses: {'ner': 5955.586147629567}
# Iteration 8, Losses: {'ner': 5791.551015521962}
# Iteration 9, Losses: {'ner': 5707.714286759366}

# %%
nlp = spacy.load("ner_fashion_model")

# %%
val_data
# Out:
#                         BrandName  \
# 306203                   richlook
# 147093                allen solly
# 274303           van heusen sport
# 329193                     gracit
# 340369                     kalini
# ...                           ...
# 173850                         uf
# 37914       hrx by hrithik roshan
# 349951            sanganeri kurti
# 202263  united colors of benetton
# 12233                   kassually
#
#                                               Description        Annotations
# 306203   fit white checked shirt men richlook slim casual  [(28, 36, BRAND)]
# 147093  allen solly men maroon white brand logo printe...   [(0, 11, BRAND)]
# 274303  van heusen sport men maroon grey slim fit tart...   [(0, 16, BRAND)]
# 329193  floral gracit pack palazzos of 2 black women p...   [(7, 13, BRAND)]
# 340369       fuchsia pack of sarees floral 2 kalini black  [(32, 38, BRAND)]
# ...                                                   ...                ...
# 173850        mustard tiered solid women stylish uf dress  [(35, 37, BRAND)]
# 37914   hrx by hrithik roshan women deep wisteria soli...   [(0, 21, BRAND)]
# 349951  sanganeri kurti women yellow pink printed flar...   [(0, 15, BRAND)]
# 202263  united colors of benetton men blue light fade ...   [(0, 25, BRAND)]
# 12233   fit printed kassually dress flare grey beige a...  [(12, 21, BRAND)]
#
# [157970 rows x 3 columns]

# %%
pred = []
for description in val_data['Description']:
    doc = nlp(description)
    flag = 0
    for ent in doc.ents:
        if ent.label_ == "BRAND": 
            flag = 1
    if flag == 1:
        pred.append(ent.text)
    else:
        pred.append('-')
    
val_data['Predictions'] = pred
val_data
# Out:
#                         BrandName  \
# 306203                   richlook
# 147093                allen solly
# 274303           van heusen sport
# 329193                     gracit
# 340369                     kalini
# ...                           ...
# 173850                         uf
# 37914       hrx by hrithik roshan
# 349951            sanganeri kurti
# 202263  united colors of benetton
# 12233                   kassually
#
#                                               Description        Annotations  \
# 306203   fit white checked shirt men richlook slim casual  [(28, 36, BRAND)]
# 147093  allen solly men maroon white brand logo printe...   [(0, 11, BRAND)]
# 274303  van heusen sport men maroon grey slim fit tart...   [(0, 16, BRAND)]
# 329193  floral gracit pack palazzos of 2 black women p...   [(7, 13, BRAND)]
# 340369       fuchsia pack of sarees floral 2 kalini black  [(32, 38, BRAND)]
# ...                                                   ...                ...
# 173850        mustard tiered solid women stylish uf dress  [(35, 37, BRAND)]
# 37914   hrx by hrithik roshan women deep wisteria soli...   [(0, 21, BRAND)]
# 349951  sanganeri kurti women yellow pink printed flar...   [(0, 15, BRAND)]
# 202263  united colors of benetton men blue light fade ...   [(0, 25, BRAND)]
# 12233   fit printed kassually dress flare grey beige a...  [(12, 21, BRAND)]
#
#                       Predictions
# 306203                   richlook
# 147093                allen solly
# 274303           van heusen sport
# 329193                     gracit
# 340369                     kalini
# ...                           ...
# 173850                         uf
# 37914       hrx by hrithik roshan
# 349951            sanganeri kurti
# 202263  united colors of benetton
# 12233                   kassually
#
# [157970 rows x 4 columns]

# %%
val_data['Success'] = val_data['BrandName'] == val_data['Predictions']

num_successes = val_data['Success'].sum()
total_rows = len(val_data)

success_percentage = (num_successes / total_rows) * 100

print(f"Success percentage: {success_percentage}%")
# Out:
# Success percentage: 98.62885357979363%

# %%
true_values = val_data['BrandName']
pred_value = val_data['Predictions']

precision = precision_score(true_values, pred_value, average='macro', zero_division=0)
recall = recall_score(true_values, pred_value, average='macro', zero_division=0)
f1 = f1_score(true_values, pred_value, average='macro', zero_division=0)
accuracy = accuracy_score(true_values, pred_value)

print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
print(f"Accuracy: {accuracy}")
# Out:
# Precision: 0.8609548422057155
# Recall: 0.8539045941024858
# F1 Score: 0.8564660653356275
# Accuracy: 0.9862885357979363
